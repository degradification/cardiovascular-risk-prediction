# %% [markdown]
# # Predicting Cardiovascular Risk Using Machine Learning

# %% [markdown]
# Cardiovascular disease (CVD) is a general term for conditions affecting the heart or blood vessels. It's usually associated with a build-up of fatty deposits inside the arteries (atherosclerosis) and an increased risk of blood clots.
#
# The dataset consists of 69301 records of patients data in 12 features, such as age, gender, systolic blood pressure, diastolic blood pressure, and etc. The target class "cardio" equals to 1, when patient has cardiovascular desease, and it's 0, if patient is healthy.
#
# **Task** - To predict the presence or absence of cardiovascular disease (CVD) using the patient examination results. Using five different models
# * Logistic Regression
# * Naive Bayes Bernoulli
# * K-Nearest Neighbor
# * Random Forest
# * Neural Network
#
# **Data description**
#
# There are 3 types of input features:
#
# *   *Objective:* factual information
# *   *Examination:* results of medical examination
# *   *Subjective:* information given by the patient

# %% [markdown]
# For all graphs which include cardio as a variable, 0 = no occurence of CVD, 1 = has CVD

# %% [markdown]
# | Feature | Variable Type | Data Type | Variable| Value Type |
# |---------|--------------|--------|----------|------------|
# | Age | Objective Feature | Continous (Ratio) | age | int (days) |
# | Height | Objective Feature | Continous (Interval) | height | int (cm) |
# | Weight | Objective Feature | Continous (Interval) | weight | float (kg) |
# | Gender | Objective Feature | Categorical (Nominal) | gender | categorical code |
# | Systolic blood pressure | Examination Feature | Continous (Interval) | ap_hi | int |
# | Diastolic blood pressure | Examination Feature | Continous (Interval) | ap_lo | int |
# | Cholesterol | Examination Feature |  Categorical (Ordinal) | cholesterol | 1: normal, 2: above normal, 3: well above normal |
# | Glucose | Examination Feature | Categorical (Ordinal) | gluc | 1: normal, 2: above normal, 3: well above normal |
# | Smoking | Subjective Feature | Categorical (Nominal) | smoke | binary |
# | Alcohol intake | Subjective Feature | Categorical (Nominal) | alco | binary |
# | Physical activity | Subjective Feature | Categorical (Nominal) | active | binary |
# | cardiovascular disease | Target Variable | Categorical (Nominal) | cardio | binary |
#
# *All of the dataset values were collected at the moment of medical examination.
#
# Credits for Dataset : [Svetlana Ulianova](https://www.kaggle.com/sulianova)
#
# Credits for Code : [RobinReni](https://www.kaggle.com/robinreni)

# %%
# Importing libraries
# https://www.kaggle.com/code/robinreni/cardiovascular-disease-eda-detailed

import numpy as np 
import pandas as pd 
import sklearn
import matplotlib as mpl
from matplotlib import pyplot as plt 
from matplotlib import rcParams
from sklearn import preprocessing
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore")

# %%
# Importing the dataset
# https://www.kaggle.com/datasets/sulianova/cardiovascular-disease-dataset?datasetId=107706&language=Python&select=cardio_train.csv
dir_data = "data/"
df = pd.read_csv(dir_data + "cardio_train.csv", sep=";")
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# Obtaining basic information of the dataframe to check the types of values in each features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
# Checking if there are any missing values in the raw dataframe
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# Checking for any duplicate values in dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Exploratory Data Analysis and Visualizations

# %%
# Visualizing the distribution of data in each feature 
df.hist(figsize=(12,14), color = "purple")
plt.show()

# %%
# From the dataset, we can see that age is in number of days, we need to change the days into years
# Later categorise the age into groups for easier implementation
def age_years(no_of_days):
  Total_days = 365.2425
  age_in_years = int(no_of_days // Total_days)
  return age_in_years

#Dividing the ages into groups
def age_groups(age_in_years):
  if 0 < age_in_years <= 10:
    return "10s"
  elif 10 < age_in_years <= 30:
    return "20s"
  elif 20 < age_in_years <= 30:
    return "30s"
  elif 30 < age_in_years <= 40:
    return "40s"
  elif 40 < age_in_years <= 50:
    return "50s"
  elif 50 < age_in_years <= 60:
    return "60s"
  elif 60 < age_in_years <= 70:
    return "70+"

# Categorizing the age groups as per the guidelines issued by 
# US National Library of Medicine National Institutes of Health
def age_categories(age_in_years):
  if 0 < age_in_years <= 2:
    return "Infants"
  elif 2 < age_in_years <= 5:
    return "Pre School Child"
  elif 5 < age_in_years <= 12:
    return "Child"
  elif 12 < age_in_years <= 19:
    return "Adolescent"
  elif 19 < age_in_years <= 24:
    return "Young Adult"
  elif 24 < age_in_years <= 44:
    return "Adult"
  elif 44 < age_in_years <= 65:
    return "Middle Aged"
  elif 65 < age_in_years:
    return "Aged"

# %%
# Adding the newly computed age, age_groups and age categorized into the dataframe
df['new_age'] = df['age'].apply(lambda x: age_years(x))
df['age_categories'] = df['new_age'].apply(lambda x: age_categories(x))
df['age_in_tees'] = df['new_age'].apply(lambda x: age_groups(x))
df.head() # Visualizing the dataframe after adding the new columns
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  new_age age_categories age_in_tees
# 0     0       1       0       50    Middle Aged         50s
# 1     0       1       1       55    Middle Aged         60s
# 2     0       0       1       51    Middle Aged         60s
# 3     0       1       1       48    Middle Aged         50s
# 4     0       0       0       47    Middle Aged         50s

# %%
# Checking the distribution of data in age_categories
rcParams['figure.figsize'] = 5, 5
sns.countplot(x ='age_categories', data = df, palette=['#432371',"#FAAE7B"])
# Out:
# <AxesSubplot:xlabel='age_categories', ylabel='count'>

# %% [markdown]
# We can see that most of the people included are from the category of middle age whereas adults form the minority of the group

# %%
#visualizing number of people exposed to the risk of CVD
rcParams['figure.figsize'] = 5, 5
sns.countplot(x ='age_categories', hue = 'cardio', data = df, palette=['#432371',"#FAAE7B"])
# Out:
# <AxesSubplot:xlabel='age_categories', ylabel='count'>

# %% [markdown]
# We can see that most of the people exposed to CVD are middle aged people including both male and female. In this case again adults form the minority.

# %%
#plot of patient's ages in years
d = sns.countplot(x='new_age', hue='cardio', data = df, palette=['#432371',"#FAAE7B"]);
d.set_xlabel('Age in Years')
sns.set(rc={'figure.figsize':(15,10)})

# %% [markdown]
# From the distribution it is difficult to say after which age the number of CVD cases are high. Hence dividing the ages into categories and visualizing could be of help which is performed in the next cell

# %%
sns.countplot(x='age_in_tees', hue='cardio', data = df, palette=['#432371',"#FAAE7B"], order = ['10s','20s','30s','40s','50s','60s','70+']);
sns.set(rc={'figure.figsize':(10,8)})

# %% [markdown]
# From the graph we can now infer that people in their 60s and ages above 70 are more exposed to the risk of CVD. We can also note that there are no CVD cases in the age group of 10 to 30.

# %% [markdown]
# Next, we will check the distribution of data considering specific features like height, alcohol and gender ratio

# %%
df.groupby('gender')['height'].mean()

# On average, men (label 2) are taller than women (label 2)
# Out:
# gender
# 1    161.355612
# 2    169.947895
# Name: height, dtype: float64

# %%
# Alcohol consumption 
df.groupby('gender')['alco'].sum()

# On average, men consume more alcohol than women
# Out:
# gender
# 1    1161
# 2    2603
# Name: alco, dtype: int64

# %%
# Gender Ratio
df['gender'].value_counts()

# There are more female patients than male
# Out:
# 1    45530
# 2    24470
# Name: gender, dtype: int64

# %%
# Checking the visual distribution in the gender feature
df['cardio'].value_counts(normalize=True)
# Out:
# 0    0.5003
# 1    0.4997
# Name: cardio, dtype: float64

# %% [markdown]
# The CVD distribution can be seen as almost equal betweem females and males

# %%
#provides a visual representation of the equal distribution of the disease and also the imbalance of genders
c = sns.countplot(x='gender', hue='cardio', data = df, palette=['#432371',"#FAAE7B"]);
c.set_xlabel('Gender: Female = 1, Male = 2')
sns.set(rc={'figure.figsize':(7,7)})

# %%
# Height Distribution 
df_graph = pd.melt(frame=df, value_vars=['height'], id_vars=['gender'])
plt.figure(figsize=(8, 8))
axis = sns.violinplot(x='variable', y='value', hue='gender', split=True, data=df_graph, scale='count', color="skyblue");

# %% [markdown]
# Compares the weight distribution of each gender using a violin plot. We can see the median, the middle dot, in the plot is around 60-70 kg.

# %% [markdown]
# Body mass index (BMI) is a measure of body fat based on height and weight that applies to adult men and women.
# Source : https://www.nhlbi.nih.gov/health/educational/lose_wt/BMI/bmicalc.htm
#
# Formula used to calculate BMI is
# BMI = kg/m2
#     kg - person's weight in kilograms;
#     m2 - height in metres squared

# %%
# calculate the BMI score 
df['BMI'] = df['weight']/((df['height']/100)**2)

# dividing the bmi score values into categories
def bmi_score_category(bmi_score):
  if 18.5 <= bmi_score <= 25:
    return "Normal"
  else:
    return "Abnormal"

df["BMI_State"] = df["BMI"].apply(lambda x: bmi_score_category(x))
df["BMI_State"].value_counts().plot(kind='pie', colors = ['#66b3ff','#99ff99'], figsize=(7, 7))
# Out:
# <AxesSubplot:ylabel='BMI_State'>

# %% [markdown]
# Shows that most of the patients tested have an abnormal weight versus normal weight.

# %% [markdown]
# Next we check how many people are prone to CVD based on the normal and abnormal BMI values

# %%
#distribution of patients based on BMI state
sns.countplot(x='BMI_State', hue='cardio', data=df, palette=['#432371',"#FAAE7B"]);
sns.set(rc={'figure.figsize':(5,5)})

# %% [markdown]
# Normal range for BMI score is 18.5 to 25. From the plot above, we can say that people who have normal BMI score are less affected by CVD compared to people with abnormal BMI score

# %% [markdown]
# In the next couple of cells we check for the factors which lead to abnormal BMI score like alcohol addiction, physical inactivity etc.

# %%
#visualizing the correlation between alcohol consumption and BMI score
sns.catplot(x="BMI_State", y="BMI" , hue="alco", col="cardio", data=df, kind="boxen", height=10, aspect=0.8, palette=sns.color_palette(['purple', 'yellow']))

# %% [markdown]
# From the graph, we can see that alcohol has not much of an impact on the BMI score

# %% [markdown]
# However, according American Health board, some of the factors that lead to the risk of CVD include hypertension, cholesterol, physical inactivity, obesity, smoking etc. In the next few sections, we try to prove if these factors are indeed the causes of CVD

# %%
# Plot to check distribution for alcohol consumption 
df["alco"].value_counts().plot(kind='pie', colors = ['#66b3ff','#99ff99'], figsize=(7, 7), ylabel = 'Alcohol: 0 = Does not Drink, 1 = Drinks Alcohol')
# Out:
# <AxesSubplot:ylabel='Alcohol: 0 = Does not Drink, 1 = Drinks Alcohol'>

# %% [markdown]
# From the piechart, most of the patients are not alcoholic

# %%
# Checking if patients are influenced by alcohol consumption
with sns.axes_style('white'):
    g = sns.factorplot("alco", data=df, aspect=2.0, kind='count', hue='cardio', palette=['#432371',"#FAAE7B"])
    g.set_ylabels('Total number of patients')
    g.set_xlabels('Alcohol: 0 = Does not Drink, 1 = Drinks Alcohol')

# %% [markdown]
# From the visualizations, we can say that alcohol does not count as a factor responsible for CVD

# %% [markdown]
# Next we will look into factors like smoking and physical inactivity

# %%
#pie chart of smokers vs non-smokers
df["smoke"].value_counts().plot(kind='pie', colors = ['#66b3ff','#99ff99'], figsize=(7, 7), ylabel = 'Smoking: 0 = non-smoker, 1 = smoker')
# Out:
# <AxesSubplot:ylabel='Smoking: 0 = non-smoker, 1 = smoker'>

# %% [markdown]
# From the distribution of data, we can see that most of the patients are the ones who do not smoke

# %% [markdown]
# Next we need to check if smoking indeed is a factor for CVD

# %%
#bar plot of Smokers vs non-Smokers, broken down into patients with CVD = 0, patients without CVD = 1 
with sns.axes_style('white'):
    g = sns.factorplot("smoke", data=df, aspect=2.0, kind='count', hue='cardio', palette=['#432371',"#FAAE7B"])
    g.set_ylabels('Total number of patients')
    g.set_xlabels('Smoking: 0 = non-smoker, 1 = smoker')

# %% [markdown]
# We can see a contradiction from the report of American Health board, that smoking is a cause of CVD. However, from the visualizations, we can see that non-smokers are more prone to CVD

# %% [markdown]
# Next we will check the distribution of data for physical inactivity

# %%
#Pie chart of physical activity of patients
df["active"].value_counts().plot(kind='pie', colors = ['#66b3ff','#99ff99'], figsize=(7, 7), ylabel = "Physical Activity: 0 = not active, 1 = active")
# Out:
# <AxesSubplot:ylabel='Physical Activity: 0 = not active, 1 = active'>

# %% [markdown]
# From the distribution we can see that people who are physically active constitute the majority of the dataset

# %%
#Bar plot of physical activity of patients withh respect to cardiovascular disease
with sns.axes_style('white'):
    g = sns.factorplot("active", data=df, aspect=2.0, kind='count', hue='cardio', palette=['#432371',"#FAAE7B"])
    g.set_ylabels('Total number of Patients')
    g.set_xlabels('Physical Activity: 0 = not active, 1 = active')

# %% [markdown]
# This visualization confirms the report of American Health board that physically active people are not prone to CVD

# %% [markdown]
# In the case of blood pressure, it is measured in terms of systolic and diastolic blood pressure. As per the American Heart Association guidelines, normal systolic pressure is 120-180mm and normal diastolic blood pressure is 80-120mm.

# %% [markdown]
# According to a recent study, the maximum blood pressure recorded was 370/360mm Hg. Hence we can drop off the values beyond the range of 250 in case of diastolic pressure and above 200 in case of systolic pressure. Before that, let's visualize if there are any outliers in our dataset

# %%
# Plotting box plot for systolic pressure
plt.figure(figsize=(8,6))
sns.boxplot(y=df["ap_hi"], palette="Set3")
# Out:
# <AxesSubplot:ylabel='ap_hi'>

# %%
# Plotting box plot for diastolic pressure
plt.figure(figsize=(8,6))
sns.boxplot(y=df["ap_lo"], palette="Set3")
# Out:
# <AxesSubplot:ylabel='ap_lo'>

# %% [markdown]
# Now we can remove the outliers and catgorize the blood pressure feature

# %%
#removing outliers
outlier_rem = ((df["ap_hi"]>250) | (df["ap_hi"]>250) | (df["ap_lo"]>200) )
df_outlier = df[~outlier_rem]

# %% [markdown]
# Now we can visualize the distribution of data after removing outliers

# %%
# Plotting box plot for systolic pressure
plt.figure(figsize=(8,6))
sns.boxplot(y=df_outlier["ap_hi"], palette="Set2")
# Out:
# <AxesSubplot:ylabel='ap_hi'>

# %%
# Plotting box plot for diastolic pressure
plt.figure(figsize=(8,6))
sns.boxplot(y=df_outlier["ap_lo"], palette="Set2")
# Out:
# <AxesSubplot:ylabel='ap_lo'>

# %% [markdown]
# Now we can categorize the blood pressure feature

# %%
from PIL import Image

image = Image.open('image.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1155x988 at 0x1F323222640>

# %%
#categorizing blood pressure based on systolic and dystolic bp
#adding new category
def bloodpressure_categories(x):
  if x['ap_hi'] < 120 and x['ap_lo'] < 80: #Categorizing the values in the normal range 
    return "Normal"
  elif 120 <= x['ap_hi'] <= 129 and x['ap_lo'] < 80:
    return "Elevated"
  elif 130 <= x['ap_hi'] <= 139 or 80 <= x['ap_lo'] <= 89:
    return "High Blood Pressure(Stage 1)"
  elif  140 <= x['ap_hi'] <= 180 or 90 <= x['ap_lo'] <= 120:
    return "High Blood Pressure(Stage 2)"
  elif  (x['ap_hi'] > 180 and  x['ap_lo'] > 120) or (x['ap_hi'] > 180 or x['ap_lo'] > 120):
    return "Hypertension Crisis"

# removing the outliers
outlier_rem = ((df["ap_hi"]>250) | (df["ap_hi"]>250) | (df["ap_lo"]>200) )
df = df[~outlier_rem]
df['blood_category'] = df.apply(bloodpressure_categories, axis=1)
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  new_age age_categories age_in_tees        BMI  \
# 0     0       1       0       50    Middle Aged         50s  21.967120
# 1     0       1       1       55    Middle Aged         60s  34.927679
# 2     0       0       1       51    Middle Aged         60s  23.507805
# 3     0       1       1       48    Middle Aged         50s  28.710479
# 4     0       0       0       47    Middle Aged         50s  23.011177
#
#   BMI_State                blood_category
# 0    Normal  High Blood Pressure(Stage 1)
# 1  Abnormal  High Blood Pressure(Stage 2)
# 2    Normal  High Blood Pressure(Stage 1)
# 3  Abnormal  High Blood Pressure(Stage 2)
# 4    Normal                        Normal

# %% [markdown]
# Now we can visualize the distribution of data in each of these categories

# %%
#pie chart of blood pressure categories: Hypertension Crisis, Elevated, Normal, High Blood Pressure (Stage 2), High Blood Pressure (Stage 1)
df["blood_category"].value_counts().plot(kind='pie', colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99'], figsize=(7, 7))
# Out:
# <AxesSubplot:ylabel='blood_category'>

# %% [markdown]
# The highest proportion of patients have Stage 1 High Blood pressure, 140 <= 'ap_hi' <= 180 or 90 <= 'ap_lo' <= 120

# %%
#bar plot of the different types of blood pressure categories with respect to CVD
with sns.axes_style('white'):
    g = sns.factorplot("blood_category", data=df, aspect=3.0, kind='count', hue='cardio', palette=['#432371',"#FAAE7B"], order=["Normal", "Elevated", "High Blood Pressure(Stage 1)", "High Blood Pressure(Stage 2)", "Hypertensive Crisis"])
    g.set_ylabels('Total number of Patients')

# %% [markdown]
# From this chart, we can say that people belonging to 'High Blood Pressure(Stage 1)' are exposed to the risk of CVD in comparison with other categories

# %% [markdown]
# Moving on to the cholesterol, as is commonly known is one of the key risk factors for CVD. We need to check visually if that is indeed the case in our dataset. The division of cholesterol feature is - 1: normal, 2: above normal, 3: well above normal

# %%
#bar plot showing different types of cholesterol with respect to CVD
with sns.axes_style('white'):
    g = sns.factorplot("cholesterol", data=df, aspect=2.0, kind='count', hue='cardio', palette=['#432371',"#FAAE7B"])
    g.set_ylabels('Total number of Patients')
    g.set_xlabels('cholesterol: 1 = normal, 2 = above normal, 3 = well above normal')

# %% [markdown]
# From the chart, we can say that people belonging to the category 'normal' are more prone to the risk of CVD

# %% [markdown]
# Next feature is glucose level. Even though glucose level does not impact CVD directly, we can still take a look at the distribution of data

# %%
#bar plot showing different types of glucose with respect to CVD
with sns.axes_style('white'):
    g = sns.factorplot("gluc", data=df, aspect=2.0, kind='count', hue='cardio', palette=['#432371',"#FAAE7B"])
    g.set_ylabels('Total number of Patients')
    g.set_xlabels('glucose: 1 = normal, 2 = above normal, 3 = well above normal')

# %% [markdown]
# Now we can select only those features which we will be using for predictions.

# %%
#new data set with features used for predictions
new_df = df[["gender","age_in_tees","BMI","BMI_State","cholesterol","gluc","active","blood_category","cardio"]].copy()
new_df.head()
# Out:
#    gender age_in_tees        BMI BMI_State  cholesterol  gluc  active  \
# 0       2         50s  21.967120    Normal            1     1       1
# 1       1         60s  34.927679  Abnormal            3     1       1
# 2       1         60s  23.507805    Normal            3     1       0
# 3       2         50s  28.710479  Abnormal            1     1       1
# 4       1         50s  23.011177    Normal            1     1       0
#
#                  blood_category  cardio
# 0  High Blood Pressure(Stage 1)       0
# 1  High Blood Pressure(Stage 2)       1
# 2  High Blood Pressure(Stage 1)       1
# 3  High Blood Pressure(Stage 2)       1
# 4                        Normal       0

# %% [markdown]
# Now we have 3 columns with categorical values viz., BMI_State, blood_category and age_in_tees. As a final step of preprocessing we need to one-hot encode these 3 columns

# %%
#preprocessing 
le = preprocessing.LabelEncoder()
# one hot encoding the age tees
le.fit(new_df['age_in_tees'])
new_df['age_in_tees'] = le.transform(new_df['age_in_tees'])
# one hot encoding the blood category
le.fit(new_df['blood_category'])
new_df['blood_category'] = le.transform(new_df['blood_category'])
#one-hot encoding the BMI_state
le.fit(new_df['BMI_State'])
new_df['BMI_State'] = le.transform(new_df['BMI_State'])
#printing out the final dataframe
new_df.head()
# Out:
#    gender  age_in_tees        BMI  BMI_State  cholesterol  gluc  active  \
# 0       2            2  21.967120          1            1     1       1
# 1       1            3  34.927679          0            3     1       1
# 2       1            3  23.507805          1            3     1       0
# 3       2            2  28.710479          0            1     1       1
# 4       1            2  23.011177          1            1     1       0
#
#    blood_category  cardio
# 0               1       0
# 1               2       1
# 2               1       1
# 3               2       1
# 4               4       0

# %%
#plotting the correlation map for all the features 
new_df.corr()
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(new_df.corr(), annot=True, linewidths=0.5, square=True, vmax=0.3, center=0, cmap=sns.cubehelix_palette())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Logistic Regression

# %%
#https://www.kaggle.com/code/raihansikdar/prognosis-of-cardiovascular-disease-using-ml/notebook#Feature-Scaling
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

#split dataset into test and train sets
X = new_df.iloc[:, 0:-1]
y = new_df.iloc[:, -1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.40, random_state=1)

# %%
#feature scaling to standardize independent features
#https://www.geeksforgeeks.org/ml-feature-scaling-part-2/#:~:text=Feature%20Scaling%20is%20a%20technique,magnitudes%20or%20values%20or%20units.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#train the model with x and y train sets
logReg = LogisticRegression()
logReg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#output the score of the training set
LOG_train = logReg.score(X_train, y_train)
LOG_train
# Out:
# 0.6395758863877886

# %%
#output the score of the test set
LOG_test = logReg.score(X_test, y_test)
LOG_test
# Out:
# 0.6340977429989494

# %%
#output of accuracy of predictions
y_pred_log = logReg.predict(X_test)
accuracy_score(y_test, y_pred_log)
# Out:
# 0.6340977429989494

# %% [markdown]
# A confusion matrix defines the performance of each machine learning model.

# %%
# value of the confusion matrix are true negative, false positive, false negative, true positive
cf_log = confusion_matrix(y_test,y_pred_log)
cf_log
# Out:
# array([[9319, 4517],
#        [5583, 8184]], dtype=int64)

# %%
#https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#:~:text=Plot%20Confusion%20Matrix%20for%20Binary%20Classes%20With%20Labels&text=You%20need%20to%20create%20a,matrix%20with%20the%20labels%20annotation.
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['figure.autolayout'] = True

ax = sns.heatmap(cf_log, annot=True, cmap='Blues')

ax.set_title('Confusion Matrix for Logistic Regression\n\n');
ax.set_xlabel('\nPredicted CVD')
ax.set_ylabel('Actual CVD ');

# Ticket labels 
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

plt.show()

# %% [markdown]
# ## Naive Bayes Bernoulli

# %%
from sklearn.naive_bayes import BernoulliNB
bernoulli = BernoulliNB()

# %%
# Training the model with x and y train sets
bernoulli.fit(X_test,y_test)
# Out:
# BernoulliNB()

# %%
# Output the score of the training set
BNB_train = bernoulli.score(X_train,y_train)
BNB_train
# Out:
# 0.6340933243164911

# %%
#output the score of the test set
BNB_test = bernoulli.score(X_test,y_test)
BNB_test
# Out:
# 0.6294605658805202

# %%
# Output of accuracy of predictions
y_pred_bnb = bernoulli.predict(X_test)
accuracy_score(y_test,y_pred_bnb)
# Out:
# 0.6294605658805202

# %%
cf_bernoulli = confusion_matrix(y_test,y_pred_bnb)
cf_bernoulli
# Out:
# array([[8750, 5086],
#        [5142, 8625]], dtype=int64)

# %%
ax = sns.heatmap(cf_bernoulli, annot=True, cmap='Blues')

ax.set_title('Confusion Matrix for Naive Bayes Bernoulli\n\n');
ax.set_xlabel('\nPredicted CVD')
ax.set_ylabel('Actual CVD ');

# Ticket labels 
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

plt.show()

# %% [markdown]
# ## K-Nearest Neighbor

# %%
# Removing the columns not of interest
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

X = new_df.drop(['cardio'], 1)
y = new_df['cardio']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
# Algorithm used K-NN model
# Train accuracy
knn_model = GridSearchCV(estimator=KNeighborsClassifier(), param_grid={'n_neighbors': [2, 3]}, cv=10).fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
acc_knn = round(knn_model.score(X_train, y_train) * 100, 2)
print(acc_knn, knn_model.best_params_)
# Out:
# 77.84 {'n_neighbors': 3}

# %%
# test accuracy
acc_test_knn = round(knn_model.score(X_test, y_test) * 100, 2)
acc_test_knn
# Out:
# 64.0

# %%
cf_knn = confusion_matrix(y_test,y_pred_knn)
cf_knn
# Out:
# array([[6672, 3770],
#        [3683, 6578]], dtype=int64)

# %%
ax = sns.heatmap(cf_knn, annot=True, cmap='Blues')

ax.set_title('Confusion Matrix for K-nearest Neighbor\n\n');
ax.set_xlabel('\nPredicted CVD')
ax.set_ylabel('Actual CVD ');

# Ticket labels 
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

plt.show()

# %% [markdown]
# ## Random Forest Classifer

# %%
X = new_df.drop(['cardio'], 1)
y = new_df['cardio']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 69007, dtype: int64

# %%
# Running a voting classifier that included random forest classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)

voting_clf = VotingClassifier(
    estimators=[('rf', rnd_clf)], 
    voting = 'hard')

# %%
#output the accuracy of RandomForest and Voting Classifiers
for clf in (rnd_clf, voting_clf):
    clf.fit(X_train, y_train)
    y_pred_clf = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred_clf))
# Out:
# RandomForestClassifier 0.6249335845046612
# VotingClassifier 0.6249335845046612

# %%
cf_rf = confusion_matrix(y_test, y_pred_clf)
cf_rf
# Out:
# array([[6753, 3689],
#        [4076, 6185]], dtype=int64)

# %%
ax = sns.heatmap(cf_rf, annot=True, cmap='Blues')

ax.set_title('Confusion Matrix for Random Forest\n\n');
ax.set_xlabel('\nPredicted CVD')
ax.set_ylabel('Actual CVD ');

# Ticket labels 
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

plt.show()

# %%
# Setting the feature names into a list
rnd_clf.feature_names = list(X_train.columns.values)

# Finding important features
feature_imp = pd.Series(rnd_clf.feature_importances_,index=rnd_clf.feature_names).sort_values(ascending=False)
feature_imp
# Out:
# BMI               0.679658
# blood_category    0.156234
# age_in_tees       0.064229
# cholesterol       0.053825
# gluc              0.016628
# active            0.010270
# gender            0.009614
# BMI_State         0.009541
# dtype: float64

# %%
# Visualizing the features
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_theme(style='darkgrid')
sns.set(font_scale = 1.5)

# Creating a bar plot
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['figure.autolayout'] = True
sns.barplot(x=feature_imp, y=feature_imp.index)

# Add labels to your graph
plt.xlabel('Feature Importance Score', size=20)
plt.ylabel('Features', size=20)
plt.title("Visualizing Important Features", size=24)
plt.tight_layout()
plt.grid(True)

plt.plot()
plt.show()

# %% [markdown]
# ## K-fold Cross-Validation

# %%
#https://machinelearningmastery.com/k-fold-cross-validation/
#https://www.kaggle.com/code/raihansikdar/prognosis-of-cardiovascular-disease-using-ml/notebook#Feature-Scaling
from sklearn.model_selection import cross_val_score

cv_score_log = cross_val_score(logReg, X_train, y_train, cv=10)
print("Logistic Regression K-fold Cross-Validation Score : ", cv_score_log.mean())
# Out:
# Logistic Regression K-fold Cross-Validation Score :  0.6369660830051604

# %%
cv_score_log = cross_val_score(bernoulli, X_train, y_train, cv=10)
print("Naive Bayes Bernoulli K-fold Cross-Validation Score : ", cv_score_log.mean())
# Out:
# Naive Bayes Bernoulli K-fold Cross-Validation Score :  0.5768259853868198

# %%
cv_score_log = cross_val_score(rnd_clf, X_train, y_train, cv=10)
print("Random Forest Classifier K-fold Cross-Validation Score : ", cv_score_log.mean())
# Out:
# Random Forest Classifier K-fold Cross-Validation Score :  0.6326804801461232

# %%
cv_score_log = cross_val_score(knn_model, X_train, y_train, cv=10)
print("K-nearest Neighbor Classifier K-fold Cross-Validation Score : ", cv_score_log.mean())
# Out:
# K-nearest Neighbor Classifier K-fold Cross-Validation Score :  0.6473377852576506

# %% [markdown]
# ## Neural Network

# %%
import keras
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Splitting the dataframe into target columns and feature set
X = new_df.drop(['cardio'], axis=1)
y = new_df['cardio']

# Initializing the Neural network
model = Sequential()
# Adding the input layer and first hidden layer
model.add(Dense(32, input_dim=8, activation='relu')) 
#adding the second hidden layer
model.add(Dense(8, activation='relu')) # applying relu activation function to remove negative values
#adding final output layer
model.add(Dense(1, activation='sigmoid')) #applying sigmoid activation function to get the probability values for each class

# %%
# Creating logs directory
import os

try:
    os.makedirs("/logs")
except FileExistsError:
    # Directory already exists
    pass

# %%
# Training the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) # We have used adam optimizer and BCE loss function for the purpose of optimization
tensor_board_CallBack = keras.callbacks.TensorBoard(log_dir='/logs', 
                                                    histogram_freq=0, 
                                                    write_graph=True, 
                                                    write_images=True)

# Training the model for 100 epoch with batch size as 16
hist = model.fit(X, y, validation_split=0.20, epochs=100, batch_size=16, callbacks=[tensor_board_CallBack])

# evaluating the performance of the model
scores = model.evaluate(X, y)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Epoch 1/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.6248 - accuracy: 0.6493 - val_loss: 0.6399 - val_accuracy: 0.6372
# Epoch 2/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5947 - accuracy: 0.6858 - val_loss: 0.5934 - val_accuracy: 0.6858
# Epoch 3/100
# 3451/3451 [==============================] - 8s 2ms/step - loss: 0.5895 - accuracy: 0.6904 - val_loss: 0.5898 - val_accuracy: 0.6925
# Epoch 4/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5866 - accuracy: 0.6929 - val_loss: 0.5865 - val_accuracy: 0.6953
# Epoch 5/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5849 - accuracy: 0.6950 - val_loss: 0.5881 - val_accuracy: 0.6924
# Epoch 6/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5837 - accuracy: 0.6990 - val_loss: 0.5853 - val_accuracy: 0.6966
# Epoch 7/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5823 - accuracy: 0.6984 - val_loss: 0.5889 - val_accuracy: 0.6929
# Epoch 8/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5818 - accuracy: 0.6994 - val_loss: 0.5860 - val_accuracy: 0.6938
# Epoch 9/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5816 - accuracy: 0.7003 - val_loss: 0.5867 - val_accuracy: 0.6949
# Epoch 10/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5808 - accuracy: 0.6994 - val_loss: 0.5834 - val_accuracy: 0.6971
# Epoch 11/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5806 - accuracy: 0.7000 - val_loss: 0.5885 - val_accuracy: 0.6919
# Epoch 12/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5803 - accuracy: 0.7006 - val_loss: 0.5854 - val_accuracy: 0.6953
# Epoch 13/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5802 - accuracy: 0.7011 - val_loss: 0.5847 - val_accuracy: 0.6961
# Epoch 14/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5799 - accuracy: 0.7006 - val_loss: 0.5869 - val_accuracy: 0.6937
# Epoch 15/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5799 - accuracy: 0.6998 - val_loss: 0.5863 - val_accuracy: 0.6938
# Epoch 16/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5794 - accuracy: 0.7023 - val_loss: 0.5830 - val_accuracy: 0.6973
# Epoch 17/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5792 - accuracy: 0.7000 - val_loss: 0.5843 - val_accuracy: 0.6966
# Epoch 18/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5791 - accuracy: 0.7017 - val_loss: 0.5847 - val_accuracy: 0.6951
# Epoch 19/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5790 - accuracy: 0.7014 - val_loss: 0.5821 - val_accuracy: 0.6981
# Epoch 20/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5789 - accuracy: 0.7016 - val_loss: 0.5827 - val_accuracy: 0.6969
# Epoch 21/100
# 3451/3451 [==============================] - 8s 2ms/step - loss: 0.5787 - accuracy: 0.7007 - val_loss: 0.5835 - val_accuracy: 0.6951
# Epoch 22/100
# 3451/3451 [==============================] - 9s 3ms/step - loss: 0.5789 - accuracy: 0.7022 - val_loss: 0.5822 - val_accuracy: 0.6969
# Epoch 23/100
# 3451/3451 [==============================] - 14s 4ms/step - loss: 0.5780 - accuracy: 0.7021 - val_loss: 0.5825 - val_accuracy: 0.6969
# Epoch 24/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5781 - accuracy: 0.7018 - val_loss: 0.5828 - val_accuracy: 0.6975
# Epoch 25/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5782 - accuracy: 0.7023 - val_loss: 0.5841 - val_accuracy: 0.6959
# Epoch 26/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5783 - accuracy: 0.7023 - val_loss: 0.5815 - val_accuracy: 0.6971
# Epoch 27/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5780 - accuracy: 0.7022 - val_loss: 0.5819 - val_accuracy: 0.6977
# Epoch 28/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5779 - accuracy: 0.7025 - val_loss: 0.5824 - val_accuracy: 0.6966
# Epoch 29/100
# 3451/3451 [==============================] - 10s 3ms/step - loss: 0.5777 - accuracy: 0.7024 - val_loss: 0.5853 - val_accuracy: 0.6979
# Epoch 30/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5777 - accuracy: 0.7029 - val_loss: 0.5862 - val_accuracy: 0.6933
# Epoch 31/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5778 - accuracy: 0.7018 - val_loss: 0.5866 - val_accuracy: 0.6957
# Epoch 32/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5778 - accuracy: 0.7025 - val_loss: 0.5820 - val_accuracy: 0.6973
# Epoch 33/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5771 - accuracy: 0.7021 - val_loss: 0.5853 - val_accuracy: 0.6959
# Epoch 34/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5777 - accuracy: 0.7018 - val_loss: 0.5856 - val_accuracy: 0.6921
# Epoch 35/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5777 - accuracy: 0.7016 - val_loss: 0.5828 - val_accuracy: 0.6971
# Epoch 36/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5775 - accuracy: 0.7027 - val_loss: 0.5828 - val_accuracy: 0.6963
# Epoch 37/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5772 - accuracy: 0.7032 - val_loss: 0.5829 - val_accuracy: 0.6976
# Epoch 38/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5775 - accuracy: 0.7019 - val_loss: 0.5816 - val_accuracy: 0.6981
# Epoch 39/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5770 - accuracy: 0.7027 - val_loss: 0.5812 - val_accuracy: 0.6968
# Epoch 40/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5771 - accuracy: 0.7027 - val_loss: 0.5832 - val_accuracy: 0.6969
# Epoch 41/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5770 - accuracy: 0.7031 - val_loss: 0.5844 - val_accuracy: 0.6958
# Epoch 42/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5771 - accuracy: 0.7023 - val_loss: 0.5834 - val_accuracy: 0.6945
# Epoch 43/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5770 - accuracy: 0.7028 - val_loss: 0.5827 - val_accuracy: 0.6976
# Epoch 44/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5772 - accuracy: 0.7033 - val_loss: 0.5822 - val_accuracy: 0.6987
# Epoch 45/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5767 - accuracy: 0.7016 - val_loss: 0.5841 - val_accuracy: 0.6982
# Epoch 46/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5772 - accuracy: 0.7031 - val_loss: 0.5827 - val_accuracy: 0.6977
# Epoch 47/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5771 - accuracy: 0.7032 - val_loss: 0.5810 - val_accuracy: 0.6971
# Epoch 48/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5770 - accuracy: 0.7021 - val_loss: 0.5831 - val_accuracy: 0.6984
# Epoch 49/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5772 - accuracy: 0.7023 - val_loss: 0.5861 - val_accuracy: 0.6934
# Epoch 50/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5773 - accuracy: 0.7033 - val_loss: 0.5818 - val_accuracy: 0.6975
# Epoch 51/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5769 - accuracy: 0.7031 - val_loss: 0.5827 - val_accuracy: 0.6972
# Epoch 52/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5767 - accuracy: 0.7038 - val_loss: 0.5829 - val_accuracy: 0.6983
# Epoch 53/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5767 - accuracy: 0.7044 - val_loss: 0.5825 - val_accuracy: 0.6982
# Epoch 54/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5765 - accuracy: 0.7031 - val_loss: 0.5830 - val_accuracy: 0.6979
# Epoch 55/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5765 - accuracy: 0.7020 - val_loss: 0.5822 - val_accuracy: 0.6992
# Epoch 56/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5767 - accuracy: 0.7036 - val_loss: 0.5816 - val_accuracy: 0.6985
# Epoch 57/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5768 - accuracy: 0.7021 - val_loss: 0.5818 - val_accuracy: 0.6986
# Epoch 58/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5764 - accuracy: 0.7034 - val_loss: 0.5862 - val_accuracy: 0.6948
# Epoch 59/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5763 - accuracy: 0.7028 - val_loss: 0.5833 - val_accuracy: 0.6977
# Epoch 60/100
# 3451/3451 [==============================] - 9s 3ms/step - loss: 0.5767 - accuracy: 0.7023 - val_loss: 0.5819 - val_accuracy: 0.6977
# Epoch 61/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5767 - accuracy: 0.7030 - val_loss: 0.5826 - val_accuracy: 0.6972
# Epoch 62/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5765 - accuracy: 0.7022 - val_loss: 0.5816 - val_accuracy: 0.6977
# Epoch 63/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5764 - accuracy: 0.7033 - val_loss: 0.5818 - val_accuracy: 0.6974
# Epoch 64/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5767 - accuracy: 0.7028 - val_loss: 0.5818 - val_accuracy: 0.6973
# Epoch 65/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5762 - accuracy: 0.7039 - val_loss: 0.5851 - val_accuracy: 0.6954
# Epoch 66/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5763 - accuracy: 0.7026 - val_loss: 0.5871 - val_accuracy: 0.6923
# Epoch 67/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5764 - accuracy: 0.7032 - val_loss: 0.5831 - val_accuracy: 0.6979
# Epoch 68/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5763 - accuracy: 0.7029 - val_loss: 0.5833 - val_accuracy: 0.6966
# Epoch 69/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5766 - accuracy: 0.7031 - val_loss: 0.5819 - val_accuracy: 0.6974
# Epoch 70/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5763 - accuracy: 0.7038 - val_loss: 0.5822 - val_accuracy: 0.6983
# Epoch 71/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5759 - accuracy: 0.7019 - val_loss: 0.5820 - val_accuracy: 0.6995
# Epoch 72/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5762 - accuracy: 0.7027 - val_loss: 0.5817 - val_accuracy: 0.6992
# Epoch 73/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5763 - accuracy: 0.7038 - val_loss: 0.5829 - val_accuracy: 0.6979
# Epoch 74/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5763 - accuracy: 0.7038 - val_loss: 0.5872 - val_accuracy: 0.6938
# Epoch 75/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5761 - accuracy: 0.7035 - val_loss: 0.5818 - val_accuracy: 0.6976
# Epoch 76/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5760 - accuracy: 0.7033 - val_loss: 0.5819 - val_accuracy: 0.6986
# Epoch 77/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5762 - accuracy: 0.7034 - val_loss: 0.5844 - val_accuracy: 0.6969
# Epoch 78/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5760 - accuracy: 0.7027 - val_loss: 0.5817 - val_accuracy: 0.6990
# Epoch 79/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5759 - accuracy: 0.7017 - val_loss: 0.5816 - val_accuracy: 0.6966
# Epoch 80/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5762 - accuracy: 0.7029 - val_loss: 0.5830 - val_accuracy: 0.6982
# Epoch 81/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5761 - accuracy: 0.7032 - val_loss: 0.5816 - val_accuracy: 0.6980
# Epoch 82/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5761 - accuracy: 0.7034 - val_loss: 0.5837 - val_accuracy: 0.6949
# Epoch 83/100
# 3451/3451 [==============================] - 8s 2ms/step - loss: 0.5761 - accuracy: 0.7031 - val_loss: 0.5842 - val_accuracy: 0.6956
# Epoch 84/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5761 - accuracy: 0.7036 - val_loss: 0.5817 - val_accuracy: 0.6978
# Epoch 85/100
# 3451/3451 [==============================] - 7s 2ms/step - loss: 0.5762 - accuracy: 0.7031 - val_loss: 0.5876 - val_accuracy: 0.6969
# Epoch 86/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5758 - accuracy: 0.7022 - val_loss: 0.5838 - val_accuracy: 0.6958
# Epoch 87/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5762 - accuracy: 0.7044 - val_loss: 0.5822 - val_accuracy: 0.6987
# Epoch 88/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5760 - accuracy: 0.7032 - val_loss: 0.5830 - val_accuracy: 0.6991
# Epoch 89/100
# 3451/3451 [==============================] - 5s 1ms/step - loss: 0.5759 - accuracy: 0.7029 - val_loss: 0.5808 - val_accuracy: 0.6989
# Epoch 90/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5759 - accuracy: 0.7028 - val_loss: 0.5839 - val_accuracy: 0.6969
# Epoch 91/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5758 - accuracy: 0.7035 - val_loss: 0.5823 - val_accuracy: 0.6982
# Epoch 92/100
# 3451/3451 [==============================] - 5s 2ms/step - loss: 0.5762 - accuracy: 0.7025 - val_loss: 0.5913 - val_accuracy: 0.6912
# Epoch 93/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5759 - accuracy: 0.7030 - val_loss: 0.5818 - val_accuracy: 0.6992
# Epoch 94/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5761 - accuracy: 0.7017 - val_loss: 0.5820 - val_accuracy: 0.6973
# Epoch 95/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5758 - accuracy: 0.7046 - val_loss: 0.5820 - val_accuracy: 0.6990
# Epoch 96/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5758 - accuracy: 0.7041 - val_loss: 0.5828 - val_accuracy: 0.6984
# Epoch 97/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5757 - accuracy: 0.7038 - val_loss: 0.5832 - val_accuracy: 0.6985
# Epoch 98/100
# 3451/3451 [==============================] - 8s 2ms/step - loss: 0.5759 - accuracy: 0.7036 - val_loss: 0.5820 - val_accuracy: 0.6978
# Epoch 99/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5758 - accuracy: 0.7040 - val_loss: 0.5858 - val_accuracy: 0.6931
# Epoch 100/100
# 3451/3451 [==============================] - 6s 2ms/step - loss: 0.5761 - accuracy: 0.7034 - val_loss: 0.5818 - val_accuracy: 0.6977
# 2157/2157 [==============================] - 3s 1ms/step - loss: 0.5760 - accuracy: 0.7033
#
# accuracy: 70.33%

# %%
# Evaluating Validation and training results for comparison
print(hist.history.keys())

# Plot for history of accuracy
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['figure.autolayout'] = True
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot for history of loss
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['figure.autolayout'] = True
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
